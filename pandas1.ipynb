# %%
import pandas as pd
veg=["brinjal","tomato","potato","peans"]

# %%
veg_Series=pd.Series(veg)

# %%
veg_Series
# Out:
# 0    brinjal
# 1     tomato
# 2     potato
# 3      peans
# dtype: object

# %%
veg_Series=pd.Series(veg, index=["purple","red","beige","green"])

# %%
veg_Series
# Out:
# purple    brinjal
# red        tomato
# beige      potato
# green       peans
# dtype: object

# %%
veg_Series["orange"]="carrot"

# %%
veg_Series
# Out:
# purple    brinjal
# red        tomato
# beige      potato
# green       peans
# orange     carrot
# dtype: object

# %%
veg_Series.drop("beige", inplace=True)

# %%
veg_Series
# Out:
# purple    brinjal
# red        tomato
# green       peans
# orange     carrot
# dtype: object

# %%
#DATA FRAME

# %%
data={"veges":["tomato","onion","carrot"],"color":["red","white","orange"],"unit":["1kg","1kg","1kg"],"max":[50,40,30],"min":[30,50,40]}
print(data)
# Out:
# {'veges': ['tomato', 'onion', 'carrot'], 'color': ['red', 'white', 'orange'], 'unit': ['1kg', '1kg', '1kg'], 'max': [50, 40, 30], 'min': [30, 50, 40]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     veges   color unit  max  min
# 0  tomato     red  1kg   50   30
# 1   onion   white  1kg   40   50
# 2  carrot  orange  1kg   30   40

# %%
df=pd.DataFrame(data, index=["A","B","C"])

# %%
df
# Out:
#     veges   color unit  max  min
# A  tomato     red  1kg   50   30
# B   onion   white  1kg   40   50
# C  carrot  orange  1kg   30   40

# %%
df["veges"]
# Out:
# A    tomato
# B     onion
# C    carrot
# Name: veges, dtype: object

# %%
df.loc["A"]
# Out:
# veges    tomato
# color       red
# unit        1kg
# max          50
# min          30
# Name: A, dtype: object

# %%
df.iloc[0,1]
# Out:
# 'red'

# %% [markdown]
# df[df["min"]>30]

# %%
df
# Out:
#     veges   color unit  max  min
# A  tomato     red  1kg   50   30
# B   onion   white  1kg   40   50
# C  carrot  orange  1kg   30   40

# %%
df[df["max"]>30]
# Out:
#     veges  color unit  max  min
# A  tomato    red  1kg   50   30
# B   onion  white  1kg   40   50

# %%
df
# Out:
#     veges   color unit  max  min    d
# A  tomato     red  1kg   50   30  veg
# B   onion   white  1kg   40   50  veg
# C  carrot  orange  1kg   30   40  veg

# %%
df.drop("d", axis=1)
# Out:
#     veges   color unit  max  min
# A  tomato     red  1kg   50   30
# B   onion   white  1kg   40   50
# C  carrot  orange  1kg   30   40

# %%
df.loc["d"]={"veges":"onion","color":"white","unit":"1kg","max":50,"min":20}

# %%
df
# Out:
#     veges   color unit max min
# A  tomato     red  1kg  50  30
# B   onion   white  1kg  40  50
# C  carrot  orange  1kg  30  40
# d   onion   white  1kg  50  20

# %%
df.drop("d", axis=1, inplace=True)

# %%
df
# Out:
#     veges   color unit max min
# A  tomato     red  1kg  50  30
# B   onion   white  1kg  40  50
# C  carrot  orange  1kg  30  40
# d   onion   white  1kg  50  20

# %%
df.drop("d", axis=0, inplace=True)

# %%
df
# Out:
#     veges   color unit max min
# A  tomato     red  1kg  50  30
# B   onion   white  1kg  40  50
# C  carrot  orange  1kg  30  40

# %%
df.isna().sum()
# Out:
# veges    0
# color    0
# unit     0
# max      0
# min      0
# dtype: int64

# %%
df.loc["d"]={"veges":"potato","color":"beige","unit":"1kg","max":"20"}

# %%
df
# Out:
#     veges   color unit max  min
# A  tomato     red  1kg  50   30
# B   onion   white  1kg  40   50
# C  carrot  orange  1kg  30   40
# d  potato   beige  1kg  20  NaN

# %%
df.isna()
# Out:
#    veges  color   unit    max    min
# A  False  False  False  False  False
# B  False  False  False  False  False
# C  False  False  False  False  False
# d  False  False  False  False   True

# %%
df.isna().sum()
# Out:
# veges    0
# color    0
# unit     0
# max      0
# min      1
# dtype: int64

# %%
df.fillna(20, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13568\3700223510.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(20, inplace=True)

# %%
df
# Out:
#     veges   color unit max  min
# A  tomato     red  1kg  50   30
# B   onion   white  1kg  40   50
# C  carrot  orange  1kg  30   40
# d  potato   beige  1kg  20   20

# %%
df.loc["e"]={"veges":"drumstick","color":"green","unit":"1kg","max":"20"}

# %%
df
# Out:
#        veges   color unit max   min
# A     tomato     red  1kg  50  30.0
# B      onion   white  1kg  40  50.0
# C     carrot  orange  1kg  30  40.0
# d     potato   beige  1kg  20  20.0
# e  drumstick   green  1kg  20   NaN

# %%
df.dropna()
# Out:
#     veges   color unit max   min
# A  tomato     red  1kg  50  30.0
# B   onion   white  1kg  40  50.0
# C  carrot  orange  1kg  30  40.0
# d  potato   beige  1kg  20  20.0

# %%
df
# Out:
#        veges   color unit max   min
# A     tomato     red  1kg  50  30.0
# B      onion   white  1kg  40  50.0
# C     carrot  orange  1kg  30  40.0
# d     potato   beige  1kg  20  20.0
# e  drumstick   green  1kg  20   NaN

# %%
df.dropna(axis=1)
# Out:
#        veges   color unit max
# A     tomato     red  1kg  50
# B      onion   white  1kg  40
# C     carrot  orange  1kg  30
# d     potato   beige  1kg  20
# e  drumstick   green  1kg  20

# %%
df
# Out:
#        veges   color unit max   min
# A     tomato     red  1kg  50  30.0
# B      onion   white  1kg  40  50.0
# C     carrot  orange  1kg  30  40.0
# d     potato   beige  1kg  20  20.0
# e  drumstick   green  1kg  20   NaN

# %%
df.dropna(axis=1, inplace=True)

# %%
df
# Out:
#        veges   color unit max
# A     tomato     red  1kg  50
# B      onion   white  1kg  40
# C     carrot  orange  1kg  30
# d     potato   beige  1kg  20
# e  drumstick   green  1kg  20

# %%
df["unit"].sum()
# Out:
# '1kg1kg1kg1kg1kg'

# %%
df["max"].count()
# Out:
# np.int64(5)

# %%
df[max].count()
# Out:
# np.int64(5)

# %%
import pandas as pd
data={"veges":["tomato","onion","carrot"],"color":["red","white","orange"],"unit":["1kg","1kg","1kg"],"max":[50,40,30],"min":[30,50,40]}
print(data)
df=pd.DataFrame(data)
# Out:
# {'veges': ['tomato', 'onion', 'carrot'], 'color': ['red', 'white', 'orange'], 'unit': ['1kg', '1kg', '1kg'], 'max': [50, 40, 30], 'min': [30, 50, 40]}

# %%
df
# Out:
#     veges   color unit  max  min
# 0  tomato     red  1kg   50   30
# 1   onion   white  1kg   40   50
# 2  carrot  orange  1kg   30   40

# %%
import pandas as pd
data={"veges":["tomato","onion","carrot"],"color":["red","white","orange"],"unit":["1kg","1kg","1kg"],"max":[50,40,30],"min":[30,50,40]}
print(data)
df1=pd.DataFrame(data)
# Out:
# {'veges': ['tomato', 'onion', 'carrot'], 'color': ['red', 'white', 'orange'], 'unit': ['1kg', '1kg', '1kg'], 'max': [50, 40, 30], 'min': [30, 50, 40]}

# %%
df1
# Out:
#     veges   color unit  max  min
# 0  tomato     red  1kg   50   30
# 1   onion   white  1kg   40   50
# 2  carrot  orange  1kg   30   40

# %%
pd.concat([df,df1], axis=1)
# Out:
#     veges   color unit  max  min   veges   color unit  max  min
# 0  tomato     red  1kg   50   30  tomato     red  1kg   50   30
# 1   onion   white  1kg   40   50   onion   white  1kg   40   50
# 2  carrot  orange  1kg   30   40  carrot  orange  1kg   30   40

# %%
pd.concat([df,df1])
# Out:
#     veges   color unit  max  min
# 0  tomato     red  1kg   50   30
# 1   onion   white  1kg   40   50
# 2  carrot  orange  1kg   30   40
# 0  tomato     red  1kg   50   30
# 1   onion   white  1kg   40   50
# 2  carrot  orange  1kg   30   40

# %%
import pandas as pd
data={"veges":["tomato","onion","carrot"],"color":["red","white","orange"],"unit":["1kg","1kg","1kg"],"max":[50,40,30],"min":[30,50,40]}
print(data)
df=pd.DataFrame(data)
# Out:
# {'veges': ['tomato', 'onion', 'carrot'], 'color': ['red', 'white', 'orange'], 'unit': ['1kg', '1kg', '1kg'], 'max': [50, 40, 30], 'min': [30, 50, 40]}

# %%
df
# Out:
#     veges   color unit  max  min
# 0  tomato     red  1kg   50   30
# 1   onion   white  1kg   40   50
# 2  carrot  orange  1kg   30   40

# %%
df["d"]=[1,2,3]

# %%
df
# Out:
#     veges   color unit  max  min  d
# 0  tomato     red  1kg   50   30  1
# 1   onion   white  1kg   40   50  2
# 2  carrot  orange  1kg   30   40  3

# %%
df.drop("d", axis=1)
# Out:
#     veges   color unit  max  min
# 0  tomato     red  1kg   50   30
# 1   onion   white  1kg   40   50
# 2  carrot  orange  1kg   30   40

# %%
pd.merge(df1,df,on="unit",how="inner")
# Out:
#   veges_x color_x unit  max_x  min_x veges_y color_y  max_y  min_y  d
# 0  tomato     red  1kg     50     30  tomato     red     50     30  1
# 1  tomato     red  1kg     50     30   onion   white     40     50  2
# 2  tomato     red  1kg     50     30  carrot  orange     30     40  3
# 3   onion   white  1kg     40     50  tomato     red     50     30  1
# 4   onion   white  1kg     40     50   onion   white     40     50  2
# 5   onion   white  1kg     40     50  carrot  orange     30     40  3
# 6  carrot  orange  1kg     30     40  tomato     red     50     30  1
# 7  carrot  orange  1kg     30     40   onion   white     40     50  2
# 8  carrot  orange  1kg     30     40  carrot  orange     30     40  3
